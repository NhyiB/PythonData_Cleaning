# %%
import pandas as pd

# %%
df = pd.read_csv('assignment.csv')

# %%
df
# Out:
#      Unnamed: 0   Title_ID               Original_Title  Release_Year  \
# 0             0  tt0111161     The Shawshank Redemption    1995-02-10
# 1             1  tt0068646                The Godfather    09 21 1972
# 2             2  tt0468569              The Dark Knight   23 -07-2008
# 3             3  tt0071562       The Godfather: Part II    1975-09-25
# 4             4  tt0110912                 Pulp Fiction    1994-10-28
# ..          ...        ...                          ...           ...
# 96           96  tt0070735                    The Sting    1974-03-21
# 97           97  tt0082096                     Das Boot    1982-03-18
# 98           98  tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99  tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100  tt0045152          Singin' in the Rain    1953-02-05
#
#          Genre Duration  Country Content_Rating              Director  \
# ...

# %% [markdown]
# ## Renaming the column headers and replacing the space with underscore

# %%
df = df.rename(columns={'Original titlÊ': 'Original_Title', 'Release year': 'Release_Year', 'IMBD title ID': 'Title_ID', 'Genrë¨': 'Genre', 'Content Rating': 'Content_Rating'})

# %%
df
# Out:
#      Unnamed: 0   Title_ID               Original_Title  Release_Year  \
# 0             0  tt0111161     The Shawshank Redemption    1995-02-10
# 1             1  tt0068646                The Godfather    09 21 1972
# 2             2  tt0468569              The Dark Knight   23 -07-2008
# 3             3  tt0071562       The Godfather: Part II    1975-09-25
# 4             4  tt0110912                 Pulp Fiction    1994-10-28
# ..          ...        ...                          ...           ...
# 96           96  tt0070735                    The Sting    1974-03-21
# 97           97  tt0082096                     Das Boot    1982-03-18
# 98           98  tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99  tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           Genre Duration       Country Content_Rating  \
# ...

# %% [markdown]
# ## Getting rid of the unnamed columns

# %%
del df['Unnamed: 8']

# %%
df
# Out:
#      Unnamed: 0   Title_ID               Original_Title  Release_Year  \
# 0             0  tt0111161     The Shawshank Redemption    1995-02-10
# 1             1  tt0068646                The Godfather    09 21 1972
# 2             2  tt0468569              The Dark Knight   23 -07-2008
# 3             3  tt0071562       The Godfather: Part II    1975-09-25
# 4             4  tt0110912                 Pulp Fiction    1994-10-28
# ..          ...        ...                          ...           ...
# 96           96  tt0070735                    The Sting    1974-03-21
# 97           97  tt0082096                     Das Boot    1982-03-18
# 98           98  tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99  tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100  tt0045152          Singin' in the Rain    1953-02-05
#
#                           Genre Duration       Country Content_Rating  \
# ...

# %% [markdown]
# ## Extracting only the first genre from the genre column

# %%
df1 = df['Genre'].str.split(',', expand = True)

# %%
df1
# Out:
#              0         1          2
# 0        Drama      None       None
# 1        Crime     Drama       None
# 2       Action     Crime      Drama
# 3        Crime     Drama       None
# 4        Crime     Drama       None
# ..         ...       ...        ...
# 96      Comedy     Crime      Drama
# 97   Adventure     Drama   Thriller
# 98     Western      None       None
# 99       Drama      None       None
# 100     Comedy   Musical    Romance
#
# [101 rows x 3 columns]

# %%
df1 = df1.rename(columns={0: 'New_Genre', 1: 'Genre_2', 2: 'Genre_3'})

# %%
df1
# Out:
#      New_Genre   Genre_2    Genre_3
# 0        Drama      None       None
# 1        Crime     Drama       None
# 2       Action     Crime      Drama
# 3        Crime     Drama       None
# 4        Crime     Drama       None
# ..         ...       ...        ...
# 96      Comedy     Crime      Drama
# 97   Adventure     Drama   Thriller
# 98     Western      None       None
# 99       Drama      None       None
# 100     Comedy   Musical    Romance
#
# [101 rows x 3 columns]

# %% [markdown]
# ### Replacing the old genre with the new extracted Genre_1

# %%
df['Genre'] = df1['New_Genre']

# %%
df
# Out:
#      Unnamed: 0   Title_ID               Original_Title  Release_Year  \
# 0             0  tt0111161     The Shawshank Redemption    1995-02-10
# 1             1  tt0068646                The Godfather    09 21 1972
# 2             2  tt0468569              The Dark Knight   23 -07-2008
# 3             3  tt0071562       The Godfather: Part II    1975-09-25
# 4             4  tt0110912                 Pulp Fiction    1994-10-28
# ..          ...        ...                          ...           ...
# 96           96  tt0070735                    The Sting    1974-03-21
# 97           97  tt0082096                     Das Boot    1982-03-18
# 98           98  tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99  tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100  tt0045152          Singin' in the Rain    1953-02-05
#
#          Genre Duration       Country Content_Rating              Director  \
# ...

# %% [markdown]
# ### Making the country column uniform

# %%
import seaborn as sb

# %%
sb.countplot(data=df,y="Country")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Country'>

# %%
df.replace(['US', 'US.'], ['USA', 'USA'], inplace=True)

# %%
df.replace(['New Zesland', 'New Zeland'], ['New Zealand', 'New Zealand'], inplace=True)

# %%
df.replace(['Italy1'], ['Italy'], inplace=True)

# %%
df.replace(['West Germany'], ['Germany'], inplace=True)

# %%
df
# Out:
#      Unnamed: 0   Title_ID               Original_Title  Release_Year  \
# 0             0  tt0111161     The Shawshank Redemption    1995-02-10
# 1             1  tt0068646                The Godfather    09 21 1972
# 2             2  tt0468569              The Dark Knight   23 -07-2008
# 3             3  tt0071562       The Godfather: Part II    1975-09-25
# 4             4  tt0110912                 Pulp Fiction    1994-10-28
# ..          ...        ...                          ...           ...
# 96           96  tt0070735                    The Sting    1974-03-21
# 97           97  tt0082096                     Das Boot    1982-03-18
# 98           98  tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99  tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100  tt0045152          Singin' in the Rain    1953-02-05
#
#          Genre Duration  Country Content_Rating              Director  \
# ...

# %%
sb.countplot(data=df,y="Country")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Country'>

# %% [markdown]
# ### Formatting the income column

# %%
df['Income'] = df['Income'].replace({'\$': '', ',': ''}, regex=True)

# %%
df
# Out:
#       Title_ID               Original_Title  Release_Year      Genre Duration  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10      Drama      142
# 1    tt0068646                The Godfather    09 21 1972      Crime      175
# 2    tt0468569              The Dark Knight   23 -07-2008     Action      152
# 3    tt0071562       The Godfather: Part II    1975-09-25      Crime      220
# 4    tt0110912                 Pulp Fiction    1994-10-28      Crime
# ..         ...                          ...           ...        ...      ...
# 96   tt0070735                    The Sting    1974-03-21     Comedy      129
# 97   tt0082096                     Das Boot    1982-03-18  Adventure      149
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20    Western      132
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21      Drama      123
# 100  tt0045152          Singin' in the Rain    1953-02-05     Comedy      103
#
# ...

# %%
replace_value = {'4o8035783':408035783}

# %%
df = df.replace({"Income": replace_values})

# %% [markdown]
# ### Cleaning the Ratings

# %%
df['Score'] = df.Score.str.extract('(\d+)')

# %%
df
# Out:
#      Unnamed: 0   Title_ID               Original_Title  Release_Year  \
# 0             0  tt0111161     The Shawshank Redemption    1995-02-10
# 1             1  tt0068646                The Godfather    09 21 1972
# 2             2  tt0468569              The Dark Knight   23 -07-2008
# 3             3  tt0071562       The Godfather: Part II    1975-09-25
# 4             4  tt0110912                 Pulp Fiction    1994-10-28
# ..          ...        ...                          ...           ...
# 96           96  tt0070735                    The Sting    1974-03-21
# 97           97  tt0082096                     Das Boot    1982-03-18
# 98           98  tt0059578  Per qualche dollaro in piÃ¹    1965-12-20
# 99           99  tt1832382      Jodaeiye Nader az Simin    2011-10-21
# 100         100  tt0045152          Singin' in the Rain    1953-02-05
#
#          Genre Duration  Country Content_Rating              Director  \
# ...

# %%
del df['Unnamed: 0']

# %%
df
# Out:
#       Title_ID               Original_Title  Release_Year      Genre Duration  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10      Drama      142
# 1    tt0068646                The Godfather    09 21 1972      Crime      175
# 2    tt0468569              The Dark Knight   23 -07-2008     Action      152
# 3    tt0071562       The Godfather: Part II    1975-09-25      Crime      220
# 4    tt0110912                 Pulp Fiction    1994-10-28      Crime
# ..         ...                          ...           ...        ...      ...
# 96   tt0070735                    The Sting    1974-03-21     Comedy      129
# 97   tt0082096                     Das Boot    1982-03-18  Adventure      149
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20    Western      132
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21      Drama      123
# 100  tt0045152          Singin' in the Rain    1953-02-05     Comedy      103
#
# ...

# %% [markdown]
# ### Cleaning the date column

# %%
import numpy as np

# %%
##df['Release_Year2'] = np.where(df['Release_Year'].str.contains('/'), pd.to_datetime(df['Release_Year']), pd.to_datetime(df['Release_Year'], dayfirst=True))

# %%
df
# Out:
#       Title_ID               Original_Title  Release_Year      Genre Duration  \
# 0    tt0111161     The Shawshank Redemption    1995-02-10      Drama      142
# 1    tt0068646                The Godfather    09 21 1972      Crime      175
# 2    tt0468569              The Dark Knight   23 -07-2008     Action      152
# 3    tt0071562       The Godfather: Part II    1975-09-25      Crime      220
# 4    tt0110912                 Pulp Fiction    1994-10-28      Crime
# ..         ...                          ...           ...        ...      ...
# 96   tt0070735                    The Sting    1974-03-21     Comedy      129
# 97   tt0082096                     Das Boot    1982-03-18  Adventure      149
# 98   tt0059578  Per qualche dollaro in piÃ¹    1965-12-20    Western      132
# 99   tt1832382      Jodaeiye Nader az Simin    2011-10-21      Drama      123
# 100  tt0045152          Singin' in the Rain    1953-02-05     Comedy      103
#
# ...
